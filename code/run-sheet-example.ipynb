# %%
import json
import datetime
import numpy as np

# %%
serial_number = "t9999"
temperature = 25
humidity = 60

# %%
experiment_data = {
    "date": str(datetime.date.today()),
    "serial_number": serial_number,
    "experimenter": ["Alice", "Bob", "Charlie", "David"],
    "temperature": temperature,
    "humidity": humidity,
    "sample_id": "PMMA-50mm",
    "channels": {
        "ch_a1": {
            "sensor-type": "PZT",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "z",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a2": {
            "sensor-type": "PZT",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "z",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a3": {
            "sensor-type": "PZT",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "z",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a4": {
            "sensor-type": "PZT",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "z",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a5": {
            "sensor-type": "ACC",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "x",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a6": {
            "sensor-type": "ACC",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_a7": {
            "sensor-type": "ACC",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "z",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b1": {
            "sensor-type": "pressure",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "normal",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b2": {
            "sensor-type": "pressure",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "shear",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b3": {
            "sensor-type": "LVDT",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b4": {
            "sensor-type": "eddy",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b5": {
            "sensor-type": "eddy",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b6": {
            "sensor-type": "eddy",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b7": {
            "sensor-type": "eddy",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        },
        "ch_b8": {
            "sensor-type": "eddy",
            "range": "500mV",
            "hysteresis": "0.001V",
            "direction": "y",
            "location": "moving-block",
            "coordinates": [0.0, 0.0, 0.0],
        }
    },
    "notes": "This is an example experiment run sheet.",
    "cycle": ["32MPa", "15MPa", "8MPa", "4MPa"]
}

# %%
print(experiment_data.keys())
print(experiment_data["date"])
print(experiment_data["cycle"][2])
print(experiment_data["channels"]["ch_a1"]["sensor-type"])
print(experiment_data["channels"]["ch_a1"]["direction"])




coo = experiment_data["channels"]["ch_a1"]["coordinates"]
print(type(coo))
print(coo)


coo = np.array(coo)
print(type(coo))
print(coo)
# Out:
# dict_keys(['date', 'serial_number', 'experimenter', 'temperature', 'humidity', 'sample_id', 'channels', 'notes', 'cycle'])
# 2025-11-23
# 8MPa
# PZT
# z
# <class 'list'>
# [0.0, 0.0, 0.0]
# <class 'numpy.ndarray'>
# [0. 0. 0.]

# %%
with open(f"../Expermant/Runsheets/{serial_number}.json", "w", encoding="utf-8") as f:
    json.dump(experiment_data, f, ensure_ascii=False, indent=4)

# %%
with open(f"../Expermant/Runsheets/{serial_number}.json", "r", encoding="utf-8") as data:
    experiment_data_load = json.load(data)
print(experiment_data_load.keys())
# Out:
# dict_keys(['date', 'serial_number', 'experimenter', 'temperature', 'humidity', 'sample_id', 'channels', 'notes', 'cycle'])
